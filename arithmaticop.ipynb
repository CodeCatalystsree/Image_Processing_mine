# %%
import cv2

# %%
import matplotlib.pyplot as plt
import numpy as py

# %%
img=cv2.imread('IPPO.JPEG',0)

plt.imshow(img)
plt.show()

# %%
img1=cv2.imread('IPPO.JPEG',0)
img2=cv2.imread('IPPO2.JPEG',0)
img2=cv2.resize(img2,(img1.shape[1],img1.shape[0]))

add_img=cv2.add(img1,img2)
add_img=cv2.cvtColor(add_img,cv2.COLOR_BGR2RGB)

plt.subplot(1,3,1)
plt.imshow(img1)
plt.subplot(1,3,2)
plt.imshow(img2)
plt.subplot(1,3,3)
plt.imshow(add_img)
plt.show()
#image addition

# %%
img1=cv2.imread('IPPO.JPEG')
img2=cv2.imread('IPPO2.JPEG')
img2=cv2.resize(img2,(img1.shape[1],img1.shape[0]))

sub_img=cv2.subtract(img1,img2)
sub_img=cv2.cvtColor(sub_img,cv2.COLOR_BGR2RGB)

plt.subplot(1,3,1)
plt.imshow(img1)
plt.subplot(1,3,2)
plt.imshow(img2)
plt.subplot(1,3,3)
plt.imshow(sub_img,cmap='gray')
plt.show()
#image subtraction

# %%
img1=cv2.imread('IPPO.JPEG',0)
img2=cv2.imread('IPPO2.JPEG',0)
img2=cv2.resize(img2,(img1.shape[1],img1.shape[0]))

mul_img=cv2.multiply(img2,img1)
mul_img=cv2.cvtColor(mul_img,cv2.COLOR_BGR2RGB)

plt.subplot(1,3,1)
plt.imshow(img1)
plt.subplot(1,3,2)
plt.imshow(img2)
plt.subplot(1,3,3)
plt.imshow(mul_img)
plt.show()
#image subtraction

# %%
img1=cv2.imread('IPPO.JPEG')
img2=cv2.imread('IPPO2.JPEG')
img2=cv2.resize(img2,(img1.shape[1],img1.shape[0]))

div_img=cv2.divide(img1,img2)
div_img=cv2.cvtColor(div_img,cv2.COLOR_BGR2RGB)

plt.subplot(1,3,1)
plt.imshow(img1)
plt.subplot(1,3,2)
plt.imshow(img2)
plt.subplot(1,3,3)
plt.imshow(div_img)
plt.show()
#image subtraction

# %%
img1=cv2.imread('IPPO.JPEG',0)
img2=cv2.imread('IPPO2.JPEG',0)
img2=cv2.resize(img2,(img1.shape[1],img1.shape[0]))

res_img=cv2.bitwise_and(img1,img2)
res_img=cv2.cvtColor(res_img,cv2.COLOR_BGR2RGB)

plt.subplot(1,3,1)
plt.imshow(img1)
plt.subplot(1,3,2)
plt.imshow(img2)
plt.subplot(1,3,3)
plt.imshow(res_img)
plt.show()
#image subtraction

# %%
img1=cv2.imread('IPPO.JPEG',0)
img2=cv2.imread('IPPO2.JPEG',0)
img2=cv2.resize(img2,(img1.shape[1],img1.shape[0]))

res_img=cv2.bitwise_or(img1,img2)
res_img=cv2.cvtColor(res_img,cv2.COLOR_BGR2RGB)

plt.subplot(1,3,1)
plt.imshow(img1)
plt.subplot(1,3,2)
plt.imshow(img2)
plt.subplot(1,3,3)
plt.imshow(res_img)
plt.show()
#image subtraction

# %%
img1=cv2.imread('IPPO.JPEG',0)
img2=cv2.imread('IPPO2.JPEG',0)
img2=cv2.resize(img2,(img1.shape[1],img1.shape[0]))

res_img=cv2.bitwise_xor(img1,img2)
res_img=cv2.cvtColor(res_img,cv2.COLOR_BGR2RGB)

plt.subplot(1,3,1)
plt.imshow(img1)
plt.subplot(1,3,2)
plt.imshow(img2)
plt.subplot(1,3,3)
plt.imshow(res_img)
plt.show()

# %%
img1=cv2.imread('IPPO.JPEG',0)
img2=cv2.imread('IPPO2.JPEG',0)
img2=cv2.resize(img2,(img1.shape[1],img1.shape[0]))

res_img=cv2.addWeighted(img1,0.5,img2,0.5,0)
res_img=cv2.cvtColor(res_img,cv2.COLOR_BGR2RGB)

plt.subplot(1,3,1)
plt.imshow(img1)
plt.subplot(1,3,2)
plt.imshow(img2)
plt.subplot(1,3,3)
plt.imshow(res_img)
plt.show()
#image avaeraging between two images

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img=cv2.imread('IPPO2.JPEG',cv2.IMREAD_GRAYSCALE)

if img is None:
    print("error")
else:
    c=255/np.log(1+np.max(img))
    log_img=c*np.log(1+img.astype(float))
    log_img=np.uint8(log_img)
    img=np.uint8(img)

    sub_img=cv2.subtract(log_img,img)

    plt.subplot(1,3,1,)
    plt.imshow(img,cmap='gray')
    plt.subplot(1,3,2)
    plt.imshow(log_img,cmap='gray')
    plt.subplot(1,3,3)
    plt.imshow(sub_img)

    plt.show()
